# %%
import pymongo
import pandas as pd
import json

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
df = pd.read_csv("../data/DF_Final.csv")

# %%
df.head()
# Out:
#    Region Country       City  Month  Day  Year  AvgTemperature       fecha  \
# 0  Europe   Spain  Barcelona      1    1  2020            52.8  2020-01-01
# 1  Europe   Spain  Barcelona      1    2  2020            49.7  2020-01-02
# 2  Europe   Spain  Barcelona      1    3  2020            50.8  2020-01-03
# 3  Europe   Spain  Barcelona      1    4  2020            50.2  2020-01-04
# 4  Europe   Spain  Barcelona      1    5  2020            50.7  2020-01-05
#
#    tmin  tmax  prcp  wspd    pres    latitud  longitud
# 0   0.0  12.0   0.0   4.2  1032.1  41.382894  2.177432
# 1   1.0  13.0   0.0   5.2  1031.8  41.382894  2.177432
# 2   2.0  11.0   0.0   4.7  1030.9  41.382894  2.177432
# 3   0.0  14.0   0.0   4.8  1031.4  41.382894  2.177432
# 4   1.0  14.0   0.0   5.6  1028.6  41.382894  2.177432

# %%
df.tail()
# Out:
#       Region Country    City  Month  Day  Year  AvgTemperature       fecha  \
# 5473  Europe   Spain  Madrid     12   27  2019            41.3  2019-12-27
# 5474  Europe   Spain  Madrid     12   28  2019            39.7  2019-12-28
# 5475  Europe   Spain  Madrid     12   29  2019            38.6  2019-12-29
# 5476  Europe   Spain  Madrid     12   30  2019            39.0  2019-12-30
# 5477  Europe   Spain  Madrid     12   31  2019            38.9  2019-12-31
#
#       tmin  tmax  prcp  wspd  pres    latitud  longitud
# 5473   4.3  13.5   0.0   0.0   0.0  40.416705 -3.703582
# 5474   2.5  13.9   0.0   0.0   0.0  40.416705 -3.703582
# 5475   2.5  13.2   0.0   0.0   0.0  40.416705 -3.703582
# 5476   2.5  11.5   0.0   0.0   0.0  40.416705 -3.703582
# 5477   2.3  11.4   0.0   0.0   0.0  40.416705 -3.703582

# %%
df.shape
# Out:
# (5478, 15)

# %%
data = df.to_dict(orient = "records")
data
# Out:
# [{'Region': 'Europe',
#   'Country': 'Spain',
#   'City': 'Barcelona',
#   'Month': 1,
#   'Day': 1,
#   'Year': 2020,
#   'AvgTemperature': 52.8,
#   'fecha': '2020-01-01',
#   'tmin': 0.0,
#   'tmax': 12.0,
#   'prcp': 0.0,
#   'wspd': 4.2,
#   'pres': 1032.1,
#   'latitud': 41.3828939,
#   'longitud': 2.1774322},
#  {'Region': 'Europe',
#   'Country': 'Spain',
#   'City': 'Barcelona',
#   'Month': 1,
#   'Day': 2,
#   'Year': 2020,
#   'AvgTemperature': 49.7,
#   'fecha': '2020-01-02',
#   'tmin': 1.0,
#   'tmax': 13.0,
#   'prcp': 0.0,
#   'wspd': 5.2,
#   'pres': 1031.8,
#   'latitud': 41.3828939,
#   'longitud': 2.1774322},
#  {'Region': 'Europe',
#   'Country': 'Spain',
#   'City': 'Barcelona',
#   'Month': 1,
#   'Day': 3,
#   'Year': 2020,
#   'AvgTemperature': 50.8,
#   'fecha': '2020-01-03',
#   'tmin': 2.0,
#   'tmax': 11.0,
#   'prcp': 0.0,
#   'wspd': 4.7,
#   'pres': 1030.9,
#   'latitud': 41.3828939,
#   'longitud': 2.1774322},
#  {'Region': 'Europe',
# ...

# %%
mydb = client["Clima_ciudades"]
print (mydb)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Clima_ciudades')

# %%
mydb.Iris.insert_many(data)
